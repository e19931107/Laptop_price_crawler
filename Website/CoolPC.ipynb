# %%
from time import sleep
from selenium import webdriver
from io import StringIO
import time
import re
import pandas as pd

option = webdriver.ChromeOptions()

option.add_experimental_option('excludeSwitches', ['enable-automation'])

driver = webdriver.Chrome(options = option)
driver.maximize_window()

url = 'https://www.coolpc.com.tw/evaluate.php'
driver.get(url)
driver.implicitly_wait(5)

dictionary = {'acer' : ['acer', '宏碁', 'Acer'],
            'asus' : ['華碩', 'ASUS', 'asus', 'Asus', 'ROG', 'TUF'],
            'dell' : ['Dell', '戴爾', 'DELL'],
            'lenovo' : ['lenovo', 'Lenovo', '聯想'],
            'hp' : ['HP', 'Hp', 'hp', '惠普'],
            'msi' : ['微星', 'msi', 'MSI',],
            'gigabyte' : ['技嘉', 'gigabyte', 'Gigabyte']}
brand = []
spec = []

for notebook, key_word in dictionary.items():
    n = 1
    while True:
        try:
            item = driver.find_element('xpath', f'//*[@id="tbdy"]/tr[2]/td[3]/select/optgroup[{n}]').text
            if notebook == 'acer':
                for acer_notebook in dictionary['acer']:
                    if acer_notebook in item:
                        spec.append(item)
                n += 1
            if notebook == 'asus':
                for asus_notebook in dictionary['asus']:
                    if asus_notebook in item:
                        spec.append(item)
                n += 1
            if notebook == 'dell':
                for dell_notebook in dictionary['dell']:
                    if dell_notebook in item:
                        spec.append(item)
                n += 1
            if notebook == 'lenovo':
                for lenovo_notebook in dictionary['lenovo']:
                    if lenovo_notebook in item:
                        spec.append(item)
                n += 1
            if notebook == 'hp':
                for hp_notebook in dictionary['hp']:
                    if hp_notebook in item:
                        spec.append(item)
                n += 1
            if notebook == 'msi':
                for msi_notebook in dictionary['msi']:
                    if msi_notebook in item:
                        spec.append(item)
                n += 1
            if notebook == 'gigabyte':
                for gigabyte_notebook in dictionary['gigabyte']:
                    if gigabyte_notebook in item:
                        spec.append(item)
                n += 1

        except:
            break
driver.close()

# Convert spec_list to DataFrame
final_df = pd.DataFrame({'Specification': spec})

# Print the final DataFrame
final_df
# Out:
#                                         Specification
# 0   Acer Aspire 3 R5-7520U/8G/512G/15吋 銀 A315-24P-...
# 1   Acer Aspire 5 i5-1335U/16G/512G/14吋 灰 A514-56M...
# 2   Acer Aspire 5 i3-1305U/8G/512G/15吋 灰 A515-58P-...
# 3   Acer Aspire 5 i5-1335U/16G/512G/17吋 灰 A517-58M...
# 4   Acer Nitro V i5-13420H/RTX2050/16G/512G/15吋 黑 ...
# ..                                                ...
# 88  技嘉 i5-12500H/RTX4060/8G/512G/15吋 黑 G5 KF-E3TW3...
# 89  技嘉 AORUS 16 i7-13700H/RTX4060/16G/1T/16吋 黑 BKF...
# 90  技嘉 AERO 14 OLED i5-12500H/RTX4050/16G/1T/14吋 銀...
# 91  技嘉 AERO 16 OLED i7-13700H/RTX4060/16G/1T/16吋 銀...
# 92  技嘉 AORUS 7 i5-12500H/RTX4050/8G/512G/17吋 黑 9MF...
#
# [93 rows x 1 columns]

# %%
from time import sleep
from selenium import webdriver
from selenium.webdriver.support.ui import Select
import time
import re
import pandas as pd

option = webdriver.ChromeOptions()

option.add_experimental_option('excludeSwitches', ['enable-automation'])

driver = webdriver.Chrome(options = option)
driver.maximize_window()

url = 'https://www.coolpc.com.tw/evaluate.php'
driver.get(url)
driver.implicitly_wait(5)

for value in range(1, 1001):
    dropdown = driver.find_element('xpath', f'//*[@id="tbdy"]/tr[2]/td[3]/select/optgroup[{n}]').text
    dropdown = driver.find_element_by_xpath('//*[@id="your_dropdown_id"]')

document.querySelector("#tbdy > tr:nth-child(2) > td:nth-child(3) > select > optgroup:nth-child(91) > option:nth-child(2)")
#tbdy > tr:nth-child(2) > td:nth-child(3) > select > optgroup:nth-child(91) > option:nth-child(2)
/html/body/form[2]/center/table/tbody/tr/td[2]/table/tbody/tr[1]/td[1]/table/tbody[2]/tr[2]/td[3]/select/optgroup[6]/option[2]/text()
/html/body/form[2]/center/table/tbody/tr/td[2]/table/tbody/tr[1]/td[1]/table/tbody[2]/tr[2]/td[3]/select/optgroup[7]/option[2]/text()
/html/body/form[2]/center/table/tbody/tr/td[2]/table/tbody/tr[1]/td[1]/table/tbody[2]/tr[2]/td[3]/select/optgroup[7]/option[3]
/html/body/form[2]/center/table/tbody/tr/td[2]/table/tbody/tr[1]/td[1]/table/tbody[2]/tr[2]/td[3]/select/optgroup[9]/option[2]
/html/body/form[2]/center/table/tbody/tr/td[2]/table/tbody/tr[1]/td[1]/table/tbody[2]/tr[2]/td[3]/select/optgroup[29]/option[1]
/html/body/form[2]/center/table/tbody/tr/td[2]/table/tbody/tr[1]/td[1]/table/tbody[2]/tr[2]/td[3]/select/optgroup[29]/option[2]
/html/body/form[2]/center/table/tbody/tr/td[2]/table/tbody/tr[1]/td[1]/table/tbody[2]/tr[2]/td[3]/select/optgroup[29]/option[4]

/html/body/form[2]/center/table/tbody/tr/td[2]/table/tbody/tr[1]/td[1]/table/tbody[2]/tr[2]/td[3]/select/optgroup[30]/option[1]
/html/body/form[2]/center/table/tbody/tr/td[2]/table/tbody/tr[1]/td[1]/table/tbody[2]/tr[2]/td[3]/select/optgroup[30]/option[4]
/html/body/form[2]/center/table/tbody/tr/td[2]/table/tbody/tr[1]/td[1]/table/tbody[2]/tr[2]/td[3]/select/optgroup[71]/option
/html/body/form[2]/center/table/tbody/tr/td[2]/table/tbody/tr[1]/td[1]/table/tbody[2]/tr[2]/td[3]/select/optgroup[85]/option[2]
/html/body/form[2]/center/table/tbody/tr/td[2]/table/tbody/tr[1]/td[1]/table/tbody[2]/tr[2]/td[3]/select/optgroup[85]/option[5]
//*[@id="tbdy"]/tr[2]/td[3]/select/optgroup[85]/option[6]
document.querySelector("#tbdy > tr:nth-child(2) > td:nth-child(3) > select > optgroup:nth-child(86) > option.r")
document.querySelector("#tbdy > tr:nth-child(2) > td:nth-child(3) > select > optgroup:nth-child(91) > option:nth-child(1)")
document.querySelector("#tbdy > tr:nth-child(2) > td:nth-child(3) > select > optgroup:nth-child(91) > option:nth-child(2)")


item = driver.find_element('xpath', f'//*[@id="tbdy"]/tr[2]/td[3]/select/optgroup[{n}]').text


<option value="460">HP 超品 i5-1235U/8G/512G/15吋 極地白 15s-fq5030TU 福利品/僅展示, $16999 ◆ ★</option>
# Out:
#                                         Specification
# 0   Acer Aspire 3 R5-7520U/8G/512G/15吋 銀 A315-24P-...
# 1   Acer Aspire 5 i5-1335U/16G/512G/14吋 灰 A514-56M...
# 2   Acer Aspire 5 i3-1305U/8G/512G/15吋 灰 A515-58P-...
# 3   Acer Aspire 5 i5-1335U/16G/512G/17吋 灰 A517-58M...
# 4   Acer Nitro V i5-13420H/RTX2050/16G/512G/15吋 黑 ...
# ..                                                ...
# 88  技嘉 i5-12500H/RTX4060/8G/512G/15吋 黑 G5 KF-E3TW3...
# 89  技嘉 AORUS 16 i7-13700H/RTX4060/16G/1T/16吋 黑 BKF...
# 90  技嘉 AERO 14 OLED i5-12500H/RTX4050/16G/1T/14吋 銀...
# 91  技嘉 AERO 16 OLED i7-13700H/RTX4060/16G/1T/16吋 銀...
# 92  技嘉 AORUS 7 i5-12500H/RTX4050/8G/512G/17吋 黑 9MF...
#
# [93 rows x 1 columns]
