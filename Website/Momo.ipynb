# %%
import requests
from bs4 import BeautifulSoup

brand_url = {'asus': '4300100008', 'ROG': '4300100673', 'acer': '4300100003', 'Lenovo': '4300100160',
            'ThinkPad': '4300100179', 'HP': '4300100013', 'Surface': '4300100759',
            'MSI': '4300100239', 'DELL': '4300100202', 'Gigabyte': '4300100446'}

headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.138 Safari/537.36'}
product_list = []
price_list = []
for brand, code in brand_url.items():
    i = 1
    while True:
        try:
            head_url = 'https://m.momoshop.com.tw/category.momo?cn='
            end_url = f'&page={i}'
            complete_url = head_url+code+end_url
            re = requests.get(complete_url, headers=headers)
            momo = BeautifulSoup(re.text, 'lxml')

            product_name = momo.select('h3[class="prdName"]')
            product_price = momo.select('b[class="price"]')
            if product_name and product_price:
                for name, price in zip(product_name[:-1], product_price[:-1]):
                    product_list.append(name.text)
                    price_list.append(price.text)
            else:
                break
            i += 1
        except:
            break

# %%
import pandas as pd

data = pd.DataFrame({'description':product_list, 'price_after': price_list})

data['price_after'] = data['price_after'].str.replace(',', '')

data['brand'] = data['description'].str.extract(r'【(.+?)】')

# 使用 str.replace 刪除原始欄位中的字元
data['description'] = data['description'].str.replace(r'【.+?】', '', regex=True)

data
# Out:
#                                             description price_after  \
# 0     14吋13代i5輕薄16G筆電-蜜誘金(VivoBook X1404VA/i5-1335U ...      19999
# 1     升級32G組★14吋i5四核16G翻轉觸控商用筆電(B7402FEA-0031A1155G7...      24111
# 2     15.6吋i5效能8G筆電(VivoBook X1502ZA/i5-1235U 10核心/8...      17999
# 3     筆電包/滑鼠組★ 14吋i7輕薄16G筆電(i7-1355U10核心/16G/512G SS...      24900
# 4     15.6吋i7輕薄筆電(VivoBook X1504VA/i7-1355U/16G/1TB ...      26999
# ...                                                 ...         ...
# 2835  15吋i5電競特仕筆電(AORUS 15 9KF-E3TW383SH-SP1/i5-1250...       35499
# 2836  15.6吋 i5 RTX4060電競筆電(G5 KF-E3TW333SH/i5-12500H...       31999
# 2837  16吋 i9 RTX 4070創作者筆電(AERO 16 OLED BSF/i9-13900...       79900
# 2838  16吋 i9 RTX4070創作者筆電(AERO 16 OLED BSF-A3TW964SP...       79900
# 2839  AERO 16 OLED 16吋NVIDIA Studio認證創作者筆(i9-13900H/...       79900
#
#             brand
# 0         ASUS 華碩
# 1            ASUS
# 2         ASUS 華碩
# 3            ASUS
# 4         ASUS 華碩
# ...           ...
# 2835  GIGABYTE 技嘉
# 2836  GIGABYTE 技嘉
# 2837  GIGABYTE 技嘉
# 2838  GIGABYTE 技嘉
# 2839  GIGABYTE 技嘉
#
# [2840 rows x 3 columns]
