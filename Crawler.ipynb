# %%
import pandas as pd
from CoolPC import CoolPC
coolpc_df = pd.DataFrame(CoolPC())

# %%
from Momo import momo
momo_df = pd.DataFrame(momo())

# %%
from Pchome import Pchome
pchome_df = pd.DataFrame(Pchome())

# %%
coolpc_df
# Out:
#     brand                                        description price_before  \
# 0    acer  Iconia Tab M10 (香檳金 / 10.1吋 / 聯發科 M8183C 八核 / ...         5111
# 1    acer  Iconia Tab P10 (鑄鐵灰 / 10.4吋 / 聯發科 M8183C 八核 / ...         6580
# 2    acer      Aspire 3 R5-7520U/8G/512G/15吋 銀 A315-24P-R6X9        14900
# 3    acer     Aspire 5 i5-1335U/16G/512G/14吋 灰 A514-56M-55H0        19900
# 4    acer  Aspire 5 i5-1335U/16G/512G/14吋 灰 A5SP14-51MTN-...        26900
# ..    ...                                                ...          ...
# 258    HP    ZBook Firefly G10 i7-1370P/16G/1T/14吋 灰 84D88PA        44900
# 259    HP  ZBook Firefly G10 i7-1360P/16G/512G/16吋 灰 84K5...        42900
# 260    HP  ZBook Power G10 i7-13700H/A500/8G/512G/15吋 灰 8...        49900
# 261    HP  ZBook Power G10 i7-13700H/A1000/8G/512G/15吋 灰 ...        55900
# 262    HP  ZBook Power G10 i7-13800H/RTX2000 Ada/16G/512G...        73900
#
#     price_after
# 0          5111
# 1          6580
# 2         14900
# ...
